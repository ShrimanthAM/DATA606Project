# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrimanthAM/DATA606Project/blob/main/DATA606_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

import pandas as pd

import glob, os
# Out:
# Mounted at /content/gdrive/

# %%
#/content/gdrive/MyDrive/DATA606/GoogleImages/images
# Out:
# gdrive	sample_data

# %%
import matplotlib.pyplot as plt
import os
import cv2
from io import BytesIO
#from PIL import Image
from IPython.display import Image



items = os.listdir('/content/gdrive/MyDrive/DATA606/GoogleImages/images')
print (items)    

for each_image in items:
  if each_image.endswith(".jpg"):
    #print (each_image)
    full_path = "/content/gdrive/MyDrive/DATA606/GoogleImages/images/" + each_image
    #print (full_path)
    print(Image(full_path))
    #im = Image.open(r'/content/gdrive/MyDrive/DATA606/GoogleImages/images/cdba407d3c.jpg')
    #im.show()
    #plt.imshow(each_image) 
    #plt.show()
    #image = cv2.imread(full_path)
    #image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#plt.figure()
#plt.imshow(image)
#plt.colorbar()
#plt.grid(False)
# Out:
# ['cdba407d3c.jpg', '76589d3af1.jpg', '60c98f6dff.jpg', '5870a297d4.jpg', 'e2a78c9887.jpg', 'ddecbd5329.jpg', '301cb27349.jpg', '5e6f125b02.jpg', '5c88452ec9.jpg', '28d6faa8cb.jpg', 'c4ff44bda7.jpg', 'e7c6fe887c.jpg', 'd75fcc23c2.jpg', '6c51bdb00f.jpg', '10af8878ad.jpg', '970d0cb44c.jpg', '9b884e2e85.jpg', '1fdc7c9ae2.jpg', 'eb10a2045f.jpg', '93fccd8198.jpg', '5674c9624f.jpg', '32ac9699c2.jpg', 'e0de9104fd.jpg', '123c0c7652.jpg', '5149e82e57.jpg', '3a379494a4.jpg', 'aefecc64e8.jpg', 'efbddbc5fd.jpg', '9d0d5f62c8.jpg', '7756dd8e96.jpg', '6526e20291.jpg', 'f78b5baa30.jpg', 'a1dd1c1bcb.jpg', 'dc6803fded.jpg', '591023cbaf.jpg', '88bbf99a6c.jpg', '237ae2ce74.jpg', '4dfea488d6.jpg', 'cc824c4313.jpg', 'f6c8dc21e6.jpg', 'e307edde61.jpg', '156937c33f.jpg', '35cc9fc8d4.jpg', '9c5d856487.jpg', '1b55839d44.jpg', 'b66362c1e1.jpg', 'b2ec516d83.jpg', '07be4f3426.jpg', '56b21c32e6.jpg', '4be1df42ee.jpg', '9c395bf2a8.jpg', '11bd2410be.jpg', '78753a86d2.jpg', '817bb3af93.jpg', '293deec779.jpg', '4906fa
# ...

# %%
# %matplotlib inline
from IPython.display import Image
Image('/content/gdrive/MyDrive/DATA606/GoogleImages/images/cdba407d3c.jpg')
